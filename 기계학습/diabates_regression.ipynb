# %%
# Colab 코드 예시

import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns

# 1. 데이터 불러오기
df = pd.read_csv("/content/drive/MyDrive/diabetes.csv")

# 2. Outcome 컬럼 제거
df = df.drop(columns=['Outcome'], errors='ignore')

# 3. X(독립변수), y(종속변수) 정의
X = df.drop(columns=['BMI'])
y = df['BMI']

# 4. 상수항 추가
X = sm.add_constant(X)

# 5. 회귀모델 피팅
model = sm.OLS(y, X).fit()

# 6. 결과 출력
print(model.summary())

# 7. 예측 vs 실제 시각화
y_pred = model.predict(X)
plt.figure(figsize=(8,6))
sns.scatterplot(x=y, y=y_pred)
plt.xlabel("Actual BMI")
plt.ylabel("Predicted BMI")
plt.title("Regression: Predicting BMI from Other Variables")
plt.plot([y.min(), y.max()], [y.min(), y.max()], 'r--')  # y=x 선
plt.show()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    BMI   R-squared:                       0.229
# Model:                            OLS   Adj. R-squared:                  0.222
# Method:                 Least Squares   F-statistic:                     32.29
# Date:                Tue, 09 Sep 2025   Prob (F-statistic):           2.34e-39
# Time:                        08:00:23   Log-Likelihood:                -2575.1
# No. Observations:                 768   AIC:                             5166.
# Df Residuals:                     760   BIC:                             5203.
# Df Model:                           7
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                       17.7841      1.338     13.293      0.000      15.158      20.410
# Pregnancies                  0.0196      0.089      0.220      0.826      -0.155       0.195
# Glucose                      0.0457      0.009      5.193      0.000       0.028       0.063
# BloodPressure                0.0764      0.014      5.527      0.000       0.049       0.104
# SkinThickness                0.1730      0.018      9.467      0.000       0.137       0.209
# Insulin                     -0.0030      0.003     -1.138      0.256      -0.008       0.002
# DiabetesPedigreeFunction     1.2427      0.781      1.590      0.112      -0.291       2.777
# Age                         -0.0173      0.027     -0.642      0.521      -0.070       0.036
# ==============================================================================
# Omnibus:                       62.311   Durbin-Watson:                   1.917
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              298.469
# Skew:                          -0.132   Prob(JB):                     1.54e-65
# Kurtosis:                       6.043   Cond. No.                         983.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
